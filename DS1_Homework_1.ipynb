# %% [markdown]
# <a href="https://colab.research.google.com/github/Adela-Jones/DS1_Homework_1_loading/blob/main/DS1_Homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json

# %%
df1='/content/Data/Home_Infusion_Therapy_Providers_Sep_21_2026.csv'
read_df1=pd.read_csv(df1)
read_df1.head(11)
# Out:
#       Enrollment ID        Legal Business Name Street Address Line 1  \
# 0   O20201116001628    CRESCENT HEALTHCARE INC       5431 SW 35TH DR
# 1   O20250730000500         KABAFUSION CO, LLC   12450 E ARAPAHOE RD
# 2   O20210121000184          I V SOLUTIONS LLC         165 HANSEN CT
# 3   O20231019000440       PERPETUAL MOBILE MED  5015 EAGLE ROCK BLVD
# 4   O20220203001062       MKARE MANAGEMENT INC        147 AUBURN RDG
# 5   O20250428002383             INFUPHARMA LLC       1239 NE 8TH AVE
# 6   O20260127003422          KABAFUSION TN LLC         2970 SIDCO DR
# 7   O20260914004301  AMERICARE HOME HEALTH INC     16501 SHERMAN WAY
# 8   O20260914004301  AMERICARE HOME HEALTH INC     16501 SHERMAN WAY
# 9   O20260914004301  AMERICARE HOME HEALTH INC     16501 SHERMAN WAY
# 10  O20260325003657                 AGIOS CORP         1314 S BAY ST
#
#    Street Address Line 2             City State    ZIP Code  \
# 0                STE 200      GAINESVILLE    FL  32608-5277
# ...

# %% [markdown]
# **DF1 represents the following:**
# Information on the providers in Medicare who specialize in Home Infusion Therapy
#
# **Columns:**
#
# **1. Enrollment ID**
#
# * Represents the enrollment ID of the provider
#
# **2. Legal Business Name**
#
# * Represents the legal business name of the organization
#
# **3. Street Address Line 1**
#
# * Represents the 1st line of the street address
#
# **4. Street Address Line 2**
#
# * Represents the 2nd line of the street address
#
# **5. City**
#
# * Represents the City the organization is located
#
# **6. State**
#
# * Represents the state the organization is located
#
# **7. ZIP Code**
#
# * Represents the ZIP Code of the organization
#
# **8. Practice Location Phone Number**
#
# * Represents the phone number of the practice location
#
# **9. Specialty Name**
#
# * Represents the providers specialty
#
# **10. Geographic Location Type Description**
#
# * Represents the geographic location of the organization
#
# **11. Geographic Location City Name**
#
# * Represents the City of the organziations geographic location
#
# **12. Geographic Location State Code**
#
# * Represents the state code of the geographic location the organization is in
#
# **13. Geographic Location ZIP Code**
#
# * Represents the ZIP Code of the geographic location the organization is in
#
# **14. State County Name**
#
# * Represents the State County name in which the practice is located

# %%
df2='/content/Data/Medicare_Telehealth_Trends_Q1_2026.csv'
read_df2=pd.read_csv(df2)
read_df2.head(11)
# Out:
#     Year  Quarter Bene_Geo_Desc Bene_Mdcd_Mdcr_Enrl_Stus Bene_Race_Desc  \
# 0   2020  Overall      National                      All            All
# 1   2020  Overall      National                      All            All
# 2   2020  Overall      National                      All            All
# 3   2020  Overall      National                      All            All
# 4   2020  Overall      National                      All            All
# 5   2020  Overall      National                      All            All
# 6   2020  Overall      National                      All            All
# 7   2020  Overall      National                      All            All
# 8   2020  Overall      National                      All            All
# 9   2020  Overall      National                      All            All
# 10  2020  Overall      National                      All            All
#
#    Bene_Sex_Desc Bene_Mdcr_Entlmt_Stus Bene_Age_Desc Bene_RUCA_Desc  \
# ...

# %% [markdown]
# **DF2 represents the following:**
#
# Information regarding Telehealth Trends extracted in Q1 2026
#
# **Columns:**
#
# **1. Year**
#
# * Identifies the year from which the data was extracted
#
# **2. Quarter**
#
# * Represents the data quarter from when the data was pulled
#
# **3. Beneficiary Geographic Description**
#
# * Provides the geographic area of the beneficiary
#
# **4. Beneficiary Medicaid Medicare Enrollment Status**
#
# * Indicates whether the beneficiary is dually eligible for both programs
#
# **5. Beneficiary Race Description**
#
# * Describes a beneficiary's racial or ethnic identity
#
# **6. Beneficiary Sex Description**
#
# * Describes the biological sex of the beneficiary
#
# **7. Beneficiary Medicare Entitlement Status**
#
# * Defines whether the beneficiary is qualified, enrolled and active to receive benefits under the Medicare program
#
# **8. Beneficiary Age Description**
#
# * Provides a breakdown of the beneficaries ages
#
# **9. Beneficiary RUCA Description**
#
# * Lists whether the beneficiary lives in an urban or rural commuting area
#
# **10. Total Beneficiary TeleHealth Eligibility**
#
# * Represents the complete count of Medicare beneficiaries who are eligible to receive Telehealth services
#
# **11. Total Part B Enrollment**
#
# * Represents the total amount of beneficiaries enrolled in Part B
#
# **12. Total Beneficiary Telehealth**
#
# * Represents the number of unique Medicare beneficiaries with Telehealth
#
# **13. Percent Telehealth**
#
# * Represents the percentage of unique Medicare beneficiaries who used a telehealth service

# %%
df3='/content/Data/Medicare_Provider_and_Supplier_Taxonomy_Crosswalk_Aug_24_2026.csv'
read_df3=pd.read_csv(df3)
read_df3.head(11)
# Out:
#    MEDICARE SPECIALTY CODE MEDICARE PROVIDER/SUPPLIER TYPE DESCRIPTION  \
# 0                       01                  Physician/General Practice
# 1                       02                   Physician/General Surgery
# 2                       02                   Physician/General Surgery
# 3                       02                   Physician/General Surgery
# 4                       02                   Physician/General Surgery
# 5                       02                   Physician/General Surgery
# 6                       02                   Physician/General Surgery
# 7                       02                   Physician/General Surgery
# 8                       02                   Physician/General Surgery
# 9                       02                   Physician/General Surgery
# 10                      02                   Physician/General Surgery
#
#    PROVIDER TAXONOMY CODE  \
# 0              208D00000X
# 1              208600000X
# 2              2086H0002X
# ...

# %% [markdown]
# **DF3 represents the following:**
#
# Information about Medicare provider/supplier Taxonomy extracted August 2026
#
# **Columns:**
#
# **1. Medicare Specialty Code**
#
# * Specialty code that corresponds to the listed Medicare specialty
#
# **2. Medicare Provider/Supplier Type Description**
#
# * The description of the Medicare provider/supplier type
#
# **3. Provider Taxonomy Description**
#
# * The taxonomy code the providers use
#
# **4. Provider Taxonomy Description: Type, Classification, Specialization**
#
# * The description of the taxonomy that the providers use

# %%
jsonf1 = '/content/Data/Air Quality & Health Impacts State of NY.json'
read_jsonf1=pd.read_json(jsonf1)
read_jsonf1.head(11)
# Out:
#                    :id           :version                      :created_at  \
# 0   row-rxsa~rtkc-tzkh  rv-dk3z~evyw.3uc4 2026-06-18 18:46:06.561000+00:00
# 1   row-ka9w~3p8v~ncvs  rv-5w28~zup2-zikn 2026-06-18 18:46:06.561000+00:00
# 2   row-vh92_d3s6-y8cr  rv-v4g7-5ycv.953x 2026-06-18 18:46:06.561000+00:00
# 3   row-pzcp-gck3_kizz  rv-6evi_aafz.tvbg 2026-06-18 18:46:06.561000+00:00
# 4   row-fm7t.gw9j-vjtm  rv-zz95~hzn5-kac4 2026-06-18 18:46:06.561000+00:00
# 5   row-2g7u~p3zf.jrvz  rv-84jd_8hge~8hbq 2026-06-18 18:46:06.561000+00:00
# 6   row-jdj3-uk6h_nrhx  rv-3nyt-y2sm~uu4v 2026-06-18 18:46:06.561000+00:00
# 7   row-a5cs_cywv-zvsz  rv-ke7q_eqhx~pbyf 2026-06-18 18:46:06.561000+00:00
# 8   row-xjff-jhs3.sv3b  rv-t9wn.nq82-p8bf 2026-06-18 18:46:06.561000+00:00
# 9   row-fkzc_vcjh.rv9e  rv-vjsn.gzwx_crdv 2026-06-18 18:46:06.561000+00:00
# 10  row-psbu.yvdc~44ym  rv-yryh_y2qt-tibw 2026-06-18 18:46:06.561000+00:00
#
#                         :updated_at  unique_id  indicator_id  \
# ...

# %% [markdown]
# **JSONF1 represents the following:**
#
# Information on New York City air quality surveillance updated as of June 2026
#
# **Columns:**
#
# **1. Unique ID**
#
# * Represents the unique record identifier
#
# **2. Indicator ID**
#
# * Identifies the type of measure value across time and space
#
#  **3. Name**
#
# * Represents the name of the indicator
#
# **4. Measure**
#
# * Represents how the Indicator is measured
#
#  **5. Measure Information**
#
# * Information such as units about the measure
#
# **6. Geography Type Name**
#
# * Represents the geography type example; Borough, Citywide
#
#  **7. Geographic Join ID**
#
# * Identifier for neighberhood geographic areas for joining to mapping geography files to make thematic maps
#
# **8. Geography Place Name**
#
# * Represents the neighborhood name
#
# **9. Time Period**
#
# * Description of the time the data applies to
#
# **10. Start Date**
#
# * Date value for the start of the time period
#
# **11. Data Value**
#
# * The data value for the indicator, measure, place and time

# %%
jsonf2='/content/Data/Leading Causes of Death US.json'
read_jsonf2=pd.read_json(jsonf2)
read_jsonf2.head(11)
# Out:
#                    :id           :version                      :created_at  \
# 0   row-s9c2_shuj.u3r7  rv-cj99_8n3p.zhnz 2019-10-24 14:19:44.587000+00:00
# 1   row-xdyq~3cey~j2k3  rv-vyyg-uv8g.yukq 2019-10-24 14:19:44.587000+00:00
# 2   row-nwn9-fqhw_h3ca  rv-yw74~mjju_uct9 2019-10-24 14:19:44.587000+00:00
# 3   row-xv2h_xkub-jcyw  rv-tpsi_pahh~cajz 2019-10-24 14:19:44.587000+00:00
# 4   row-3kd4~edcb.rsvd  rv-bfrt~542p_dtk9 2019-10-24 14:19:44.587000+00:00
# 5   row-xjwv.gc2r.3hdi  rv-eatw_ru2q_82pq 2019-10-24 14:19:44.587000+00:00
# 6   row-g7y2.wym8_hcu2  rv-9c9z-wmyf-e5eg 2019-10-24 14:19:44.587000+00:00
# 7   row-tts4_akwe-amn7  rv-kjuh_2yhg-26g6 2019-10-24 14:19:44.587000+00:00
# 8   row-qgw8-m7pt-dtst  rv-q9vx~6wf9_ezdt 2019-10-24 14:19:44.587000+00:00
# 9   row-yu4c~bw4t.vz24  rv-kz9b_kqs3.9nyt 2019-10-24 14:19:44.587000+00:00
# 10  row-j9w8_ubfz_f5y3  rv-ya9q_ai9j~iuzf 2019-10-24 14:19:44.587000+00:00
#
#                         :updated_at  year  \
# ...

# %% [markdown]
# **JSONF2 Represents the following:**
#
# Age adjusted death rates for the 10 leading causes of death in the United States beginning in 1999
#
# **Columns:**
#
# **1. Year**
#
# * Represents the year the death occurred
#
# **2. 113 Cause Name**
#
# * Represents a specific standardized subcategories of death as created by the National Center for Health Statistics
#
# **3. Cause Name**
#
# * Represents the simplified category name for the leading causes of death such as Heart Disease, Cancer or Stroke
#
# **4. State**
#
# * The geographic location where the death occurred
#
# **5. Deaths**
#
# * Represents the total number of individuals who died from that specific cause
#
# **6. Age Adjusted Death Rate**
#
# * Represents the number of deaths per 100,000 people

# %%
jsonf3='/content/Data/Lottery Mega Millions Winning Numbers.json'
read_jsonf3=pd.read_json(jsonf3)
read_jsonf3.head(11)
# Out:
#                    :id           :version                      :created_at  \
# 0   row-2zvw.8wby-6cep  rv-mt2j~ifde_qeuc 2026-09-23 07:33:07.315000+00:00
# 1   row-j77p.ica4-izwc  rv-tfvb~ctw4_gzpp 2026-09-19 07:33:06.054000+00:00
# 2   row-9pzr~94di-vevh  rv-sgt2-2dvi-ekew 2026-09-16 12:13:50.450000+00:00
# 3   row-5zd2-mht4~d3jr  rv-r73e~wusa-79n9 2026-09-12 07:33:10.707000+00:00
# 4   row-nevm-2g3h~4dbj  rv-g2d3.vvjx_puti 2026-09-09 07:33:12.882000+00:00
# 5   row-ehe5_z79c.4xz2  rv-mxc3.dfhs-yp75 2026-09-05 07:33:20.350000+00:00
# 6   row-eks8-sfs4_x4vc  rv-89w7_496a-ajmv 2026-09-02 07:33:00.409000+00:00
# 7   row-taca~tvhe_5jru  rv-nf9k_2bc8-u75s 2026-08-29 07:32:59.950000+00:00
# 8   row-7ct3~jj86-xnt3  rv-ttgf_47td_v5xv 2026-08-26 07:33:31.658000+00:00
# 9   row-y8rt_knix.hnix  rv-7x4g_wz38-f8gc 2026-08-22 07:32:56.423000+00:00
# 10  row-swtx~np9f~qmyh  rv-xdxb~f73v-u6ve 2026-08-19 20:59:08.994000+00:00
#
# ...

# %% [markdown]
# **JSONF3 represents the following:**
#
# NY State Lottery Mega Millions Winning Numbers beginning in 2002
#
# **Columns:**
#
# **1. Draw Date**
#
# * The exact date the drawing took place
#
# **2. Winning Numbers**
#
# * Represents the numbers that were drawn
#
# **3. Mega Ball**
#
# * Represents the number that was drawn as the Mega Ball
#
# **4. Multiplier**
#
# *  Represents the multiplier that will be randomly assigned to the drawing. It could be a value of 2x, 3x or 4x

# %%
excelf1='/content/Data/Motor_Vehicle_Occupant_Death_Rate,_by_Age_and_Sex,_2012_&_2014,_All_States_20260923.xlsx'
read_excelf1=pd.read_excel(excelf1)
read_excelf1.head(11)
# Out:
#                    State                                         Location  \
# 0                Alabama                 Alabama  (32.839182, -86.631125)
# 1                 Alaska                 Alaska  (64.836661, -147.738891)
# 2                Arizona                Arizona  (34.869712, -111.760902)
# 3               Arkansas                Arkansas  (34.748745, -92.275105)
# 4             California             California  (37.640735, -121.002435)
# 5               Colorado               Colorado  (38.841772, -106.132562)
# 6            Connecticut             Connecticut  (41.544654, -72.651713)
# 7               Delaware                Delaware  (39.008676, -75.574561)
# 8   District of Columbia    District of Columbia  (38.892062, -77.019912)
# 9                Florida                 Florida  (28.915325, -81.922409)
# 10               Georgia                 Georgia  (32.836038, -83.631709)
#
#     All Ages, 2012  All Ages, 2014  Age 0-20, 2012  Age 0-20, 2014  \
# ...

# %% [markdown]
# **Excel F1 represents the following:**
#
# Rate and deaths by age/sex per 100,000 population for motor vehicle occcupants killed in crashes from 2012 & 2014
#
# **Columns:**
#
# **1. State**
#
# * State where the death occurred.
#
# **2. Location**
#
# * Location of where the death occurred
#
# **3. All Ages 2012**
#
# * Represents the total number of motor vehicle occupants of any age killed in a traffic crash during 2012
#
# **4. All Ages 2014**
#
# * Represents the total number of motor vehicle occupants of any age killed in a traffic crash during 2014
#
# **5. Age 0-20, 2012**
#
# * Total number of occupants ages 0-20 killed in a traffic crash during 2012
#
# **6. Age 0-20, 2014**
#
# * Total number of occupants ages 0-20 killed in a traffic crash during 2014
#
# **7. Age 21-34, 2012**
#
# * Total number of occupants ages 21-34 killed in a traffic crash during 2012
#
# **8. Age 21-34, 2014**
#
# * Total number of occupants ages 21-34 killed in a traffic crash during 2014
#
# **9. Age 35-54, 2012**
#
# * Total number of occupants ages 35-54 killed in a traffic crash during 2012
#
# **10. Age 35-54, 2014**
#
# * Total number of occupants ages 35-54 killed in a traffic crash during 2014
#
# **11. Age 55+, 2012**
#
# * Total number of occupants ages 55+ killed in a traffic crash during 2012
#
# **12. Age 55+, 2014**
#
# * Total number of occupants ages 55+ killed in a traffic crash during 2014
#
# **13. Male, 2012**
#
# * Total number of male occupants killed in a traffic crash in 2012
#
# **14. Male, 2014**
#
# * Total number of male occupants killed in a traffic crash in 2014
#
# **15. Female, 2012**
#
# * Total number of female occupants killed in a traffic crash in 2012
#
# **16. Female, 2014**
#
# * Total number of female occupants killed in a traffic crash in 2014

# %%
excelf2='/content/Data/School-Fine- Reports 2010.xlsx'
read_excelf2=pd.read_excel(excelf2)
read_excelf2.head(11)
# Out:
#    Fines Imposed by Federal Student Aid in Fiscal Year 2010  \
# 0                                               OPEID
# 1                                            02280500
# 2                                            03445300
# 3                                            02098800
# 4                                            03698400
# 5                                            02125000
# 6                                            03162300
# 7                                            00565500
# 8                                            02228500
# 9                                            01047400
# 10                                           03590400
#
#                                       Unnamed: 1           Unnamed: 2  \
# 0                                         School                 City
# 1                Charles of Italy Beauty College     Lake Havasu City
# 2                    HDS Truck Driving Institute               Tucson
# ...

# %% [markdown]
# **Excel F2 represents the following:**
#
# Information regarding eligibility and compliance reports about the approximately 6,000 post secondary institutions that participate in the Title IV programs and fines imposed for the year 2010
#
# **Columns:**
#
# **1. OPEID**
#
# * Represents the unique 8 digit identification code assigned by the U.S Dept. of education to colleges, universities and technical schools
#
# **2. School**
#
# * The name of the School
#
# **3. City**
#
# *City where the school is physically located
#
# **4. State**
#
# * State where the school is located
#
# **5. School Type**
#
# * Represents if the school is private, public or proprietary
#
#
# **6. Referral Reason**
#
# * The reason why the school was flagged
#
# **7. Imposed Fine Amount**
#
# * The exact dollar amount penalty the school is ordered to pay
#
# **8. Imposed Fine Date**
#
# * The offical date the imposed fine was finalized and issued to the school

# %%
excelf3='/content/Data/2026-9-18-iolp-buildings.xlsx'
read_excelf3=pd.read_excel(excelf3)
read_excelf3.head(11)
# Out:
#    Location Code                        Real Property Asset Name  \
# 0         AK0001             ANCHORAGE HISTORIC FEDERAL BUILDING
# 1         AK0005                      KETCHIKAN FEDERAL BUILDING
# 2         AK0009                            POST OFFICE AND CU H
# 3         AK0013    HURFF A. SAUNDERS FB & ROBERT BOOCHEVER USCH
# 4         AK0029                      FAIRBANKS FEDERAL BUILDING
# 5         AK0031  ANCHORAGE FED. BLDG & JAMES M. FITZGERALD USCH
# 6         AK0032  ANCHORAGE FEDERAL BUILDING US COURTHOUSE ANNEX
# 7         AK0036                       ALCAN RECREATION BUILDING
# 8         AK0037                             ALCAN POLE BUILDING
# 9         AK0038                  POKER CREEK LAND PORT OF ENTRY
# 10        AK0040                                ALCAN LAND LEASE
#
#     Installation Name Owned or Leased  GSA Region              Street Address  \
# 0   ANCHORAGE FEDERAL           OWNED          10               605 W 4TH AVE
# ...

# %% [markdown]
# **Excel F3 represents the following information:**
#
# Inventory of owned and Leased properties leased by the General Services Administration across the United States, Puerto Rico, Guam, and American Samoa.
#
# **Columns:**
#
# **1. Location Code**
#
# * Represents the unique code to identify the sepcific building or property
#
# **2. Real Property Asset Name**
#
# * The common name or title of the building
#
# **3. Installation Name**
#
# * Identifies whether the property belongs to a larger installation
#
# **4. Owned or Leased**
#
# * Indicates whether the federal government owns or rents the property
#
# **5. GSA Region**
#
# * The geographic region assigned by the GSA
#
# **6. Street Region**
#
# * The street address of the property
#
# **7. City**
#
# * The City where the property is located
#
# **8. Zip Code**
#
# * The postal ZIP Code of  the property
#
# **9. Latitude**
#
# * Represents the geographic GPS coordinates used for mapping the building
#
# **10. Longitude**
#
# * Represents the geographic GPS coordinates used for mapping the building
#
# **12. Building Rentable Square Feet**
#
# * The total rentable square footage available inside the building structure
#
# **13. Available Square Feet**
#
# * The amount of vacant usable spacve ready for occupancy
#
# **14. Construction Date**
#
# * The date the buildings construction was originally finished
#
# **15. Congressional District**
#
# * Represents the specific federal congressional district where the property is physically located
#
# **16. Congressional District Representative Name**
#
# * The name of the U.S Representative serving the district
#
# **17. Bulding Status**
#
# * Describes the operational state of the property
#
# **18. Real Property Asset Type**
#
# * Classifies whether the property is a building, land or a structure
